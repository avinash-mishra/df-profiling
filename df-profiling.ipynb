# %%
import pandas as pd
import pandas_profiling as pp
import pixiedust as px

# %%
df = pd.read_csv('data/hoge.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  A1  A2  A3  A4  A5
# 0           1   1   0   0   1   0
# 1           2   0   1   0   1   0
# 2           3   1   0   1   1   1
# 3           4   1   1   0   0   1
# 4           5   0   1   1   1   0

# %%
pp.ProfileReport(df)
# Out:
# /Users/avinash/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
# ...

# %%
px.display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure1f1621a0" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>
